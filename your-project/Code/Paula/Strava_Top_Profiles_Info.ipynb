# %%
#importing libraries

import pandas as pd
import requests
import re 
import json 
from bs4 import BeautifulSoup as Soup

# %% [markdown]
# #### Since we have the problem of data privacy in Strava, let's try to get the names and IDs of the top pros in Strava by web scraping.
# #### This will give us hopefully enough info to perform our analysis.We need to grab their name, their id and their data preferences

# %%
url = "https://www.strava.com/pros"

#let's request the info
page = requests.get(url)
soup = Soup(page.content, "html.parser")

# %% [markdown]
# #### This gives us the the name of the profiles or the usernames in Strava

# %%
top_profiles = [element.get_text() for element in soup.select("div ul.pros")[0].select("h3 a.minimal")]

# %%
len(top_profiles)
# Out:
# 1957

# %% [markdown]
# #### This gives us the complete url to access to each of the top profiles pages

# %%
top_profiles_url = [element['href'] for element in soup.select("div ul.pros")[0].select("h3 a.minimal")]

# %%
top_profiles_url[1956] #showing first 50 results
len(top_profiles_url)
# Out:
# 1957

# %% [markdown]
# #### We are now retrieving the IDs from each of the profiles

# %%
#We now have the names of the pro athletes and their url, let's look for their id and their data rights.
#First, we complete the urls with the remaining part of the https_ : https://www.strava.com

absolute_url = []

for element in top_profiles_url:
    url_root = "https://www.strava.com"
    absolute_url.append(url_root + element)

# %%
absolute_url[1956]
# Out:
# 'https://www.strava.com/pros/gledhill_leon'

# %%
#Now we retrieve the id for each url 

#let's try with the first one
url_1= absolute_url[1956]
page_1 = requests.get(url_1)
soup_1 = Soup(page_1.content, "html.parser")

#Let's call the href where the id is located and clean the link so we only weep the number id
id_profile = soup_1.select("div.spans5 a.button")[0]["href"]
id_profile
re.findall(r"(?<=content=)\d*", id_profile) 
#now we find a pattern to retrieve all the id numbers, let's do it for each url in absolute_url
# Out:
# ['4428304']

# %%
absolute_url[500]
# Out:
# 'https://www.strava.com/pros/rfahringer'

# %% [markdown]
# ### We create a list with all the ids for the top athletes

# %%
list_ids = []
#We create an empty list to populate with all the ids and retrieve each url to find their number like above
for soup in trial:
    url = soup
    page = requests.get(url)
    soup_1 = Soup(page.content, "html.parser")
    id_profile = soup_1.select("div.spans5 a.button")[0]["href"]
    id_finale = re.findall(r"(?<=content=)\d*", id_profile)
    list_ids.append(id_finale)

# %%
list_ids= list_ids[0:1958]

# %%
#Since out output was a list of lists, we flatten it. 

flattened_list_ids = [item for sublist in list_ids for item in sublist]
len(flattened_list_ids)
# Out:
# 1956

# %%
#we do the same for the other trials:

list_ids_1 = []
#We create an empty list to populate with all the ids and retrieve each url to find their number like above
for soup in trial_1:
    url = soup
    page = requests.get(url)
    soup_1 = Soup(page.content, "html.parser")
    id_profile = soup_1.select("div.spans5 a.button")[0]["href"]
    id_finale = re.findall(r"(?<=content=)\d*", id_profile)
    list_ids_1.append(id_finale)

# %%
list_ids_1
# Out:
# [['669507'],
#  ['255147'],
#  ['729308'],
#  ['21378496'],
#  ['1038655'],
#  ['50693'],
#  ['7780234'],
#  ['1630827'],
#  ['9393290'],
#  ['281953'],
#  ['13176333'],
#  ['880909'],
#  ['12615695'],
#  ['4106785'],
#  ['7208211'],
#  ['5526389'],
#  ['1758856'],
#  ['3340479'],
#  ['402439'],
#  ['15610991'],
#  ['279500'],
#  ['4716562'],
#  ['8527415'],
#  ['119832'],
#  ['22433281'],
#  ['321346'],
#  ['1083906'],
#  ['3395561'],
#  ['1130255'],
#  ['41161380'],
#  ['5599966'],
#  ['1695462'],
#  ['2207736'],
#  ['9759708'],
#  ['2709284'],
#  ['563244'],
#  ['16155364'],
#  ['11391842'],
#  ['3841158'],
#  ['19311323'],
#  ['30683682'],
#  ['4905731'],
#  ['3243335'],
#  ['1000882'],
#  ['553380'],
#  ['200147'],
#  ['3125765'],
#  ['8133029'],
#  ['4851916'],
#  ['2490308'],
#  ['21620962'],
#  ['27185541'],
#  ['1400765'],
#  ['364482'],
#  ['3507951'],
#  ['1841156'],
#  ['1741458'],
#  ['683033'],
#  ['3415999'],
#  ['16212440'],
#  ['13568823'],
#  ['2360736'],
#  ['263443'],
#  ['723518'],
#  ['4276994'],
#  ['3455800'],
#  ['21198621'],
#  ['7491815'],
#  ['270912'],
#  ['1711357'],
#  ['9472341'],
#  ['42057509'],
#  ['2194005'],
#  ['8644778'],
#  ['2271600'],
#  ['6188'],
#  ['16362182'],
#  ['11983582'],
#  ['260628'],
#  ['2406083'],
#  ['19953932'],
#  ['2937395'],
#  ['4592180'],
#  ['115083'],
#  ['22512043'],
#  ['16182341'],
#  ['612282'],
#  ['5052895'],
#  ['1886659'],
#  ['184950'],
#  ['2806297'],
#  ['4774417'],
#  ['381795'],
#  ['24644516'],
#  ['337576'],
#  ['2354874'],
#  ['2918560'],
#  ['13598491'],
#  ['10232221'],
#  ['20563926'],
#  ['378624'],
#  ['4910484'],
#  ['1657853'],
#  ['2159156'],
#  ['1162039'],
#  ['10809463'],
#  ['432354'],
#  ['49803746'],
#  ['9224252'],
#  ['13872795'],
#  ['1216273'],
#  ['6744457'],
#  ['1358661'],
#  ['1141634'],
#  ['4532614'],
#  ['2213214'],
#  ['1689651'],
#  ['5329526'],
#  ['578640'],
#  ['6037156'],
#  ['17111737'],
#  ['2920206'],
#  ['2957348'],
#  ['1803232'],
#  ['188734'],
#  ['15210607'],
#  ['1071647'],
#  ['6137589'],
#  ['3376822'],
#  ['1809256'],
#  ['1074765'],
#  ['16257252'],
#  ['11997777'],
#  ['6265105'],
#  ['2453180'],
#  ['192085'],
#  ['1662769'],
#  ['5651685'],
#  ['1413161'],
#  ['4411135'],
#  ['371357'],
#  ['1843013'],
#  ['4468784'],
#  ['9479785'],
#  ['278502'],
#  ['303084'],
#  ['6448444'],
#  ['547053'],
#  ['5954157'],
#  ['974099'],
#  ['11435413'],
#  ['630070'],
#  ['71957'],
#  ['9803888'],
#  ['4498913'],
#  ['1124501'],
#  ['9068'],
#  ['1649830'],
#  ['231604'],
#  ['4347433'],
#  ['4056360'],
#  ['3539975'],
#  ['2116733'],
#  ['384548'],
#  ['34895835'],
#  ['1602857'],
#  ['14451'],
#  ['15932405'],
#  ['1959152'],
#  ['16068533'],
#  ['18663033'],
#  ['284774'],
#  ['5127538'],
#  ['1466519'],
#  ['4551860'],
#  ['10573633'],
#  ['277969'],
#  ['867729'],
#  ['5474'],
#  ['57225497'],
#  ['2357529'],
#  ['1751647'],
#  ['359688'],
#  ['2289445'],
#  ['1876677'],
#  ['5543279'],
#  ['116788'],
#  ['4725228'],
#  ['1367309'],
#  ['563273'],
#  ['623032'],
#  ['149300'],
#  ['335746'],
#  ['132899'],
#  ['183904'],
#  ['8412547'],
#  ['8288236'],
#  ['12924172'],
#  ['68120'],
#  ['1893314'],
#  ['335369'],
#  ['269660'],
#  ['134614'],
#  ['2041772'],
#  ['283726'],
#  ['1416243'],
#  ['296844'],
#  ['7068194'],
#  ['15656336'],
#  ['199092'],
#  ['16061889'],
#  ['1316333'],
#  ['14762808'],
#  ['1937992'],
#  ['32132781'],
#  ['2754904'],
#  ['1005040'],
#  ['278195'],
#  ['1212323'],
#  ['4048714'],
#  ['1223199'],
#  ['1187926'],
#  ['513412'],
#  ['2560531'],
#  ['1760211'],
#  ['10265'],
#  ['3052716'],
#  ['3930966'],
#  ['2911188'],
#  ['6281490'],
#  ['1845301'],
#  ['5574348'],
#  ['4666728'],
#  ['10513261'],
#  ['9325571'],
#  ['2686441'],
#  ['189094'],
#  ['45051544'],
#  ['1045728'],
#  ['2905502'],
#  ['1120791'],
#  ['605510'],
#  ['2107988'],
#  ['10400121'],
#  ['19837380'],
#  ['207840'],
#  ['16010204'],
#  ['601041'],
#  ['1260560'],
#  ['4681346'],
#  ['1754389'],
#  ['304929'],
#  ['713550'],
#  ['26919111'],
#  ['1252953'],
#  ['28950255'],
#  ['2615414'],
#  ['1005867'],
#  ['17555014'],
#  ['11152709'],
#  ['42139655'],
#  ['11486080'],
#  ['25809849'],
#  ['8471540'],
#  ['3621657'],
#  ['593390'],
#  ['373174'],
#  ['9644'],
#  ['17046618'],
#  ['1291943'],
#  ['135819'],
#  ['776985'],
#  ['670999'],
#  ['13592'],
#  ['1760759'],
#  ['12486720'],
#  ['1194434'],
#  ['40898227'],
#  ['806678'],
#  ['8843343'],
#  ['3585800'],
#  ['19150197'],
#  ['26853748'],
#  ['998674'],
#  ['6850122'],
#  ['6701875'],
#  ['306330'],
#  ['1088533'],
#  ['185890'],
#  ['41812275'],
#  ['340943'],
#  ['2368262'],
#  ['279726'],
#  ['58171327'],
#  ['5139200'],
#  ['913823'],
#  ['180305'],
#  ['45602268'],
#  ['288769'],
#  ['173213'],
#  ['5889'],
#  ['43684184'],
#  ['6992780'],
#  ['118945'],
#  ['222335'],
#  ['11673347'],
#  ['323139'],
#  ['357054'],
#  ['120454'],
#  ['22241860'],
#  ['39780460'],
#  ['58120'],
#  ['807761'],
#  ['21659897'],
#  ['2547704'],
#  ['2283295'],
#  ['6020142'],
#  ['3418802'],
#  ['338452'],
#  ['781231'],
#  ['4395'],
#  ['817333'],
#  ['135919'],
#  ['1714205'],
#  ['7917995'],
#  ['1361755'],
#  ['10563833'],
#  ['4957556'],
#  ['21354533'],
#  ['4993592'],
#  ['59707591'],
#  ['3232281'],
#  ['1406897'],
#  ['3435263'],
#  ['461374'],
#  ['261192'],
#  ['4322914'],
#  ['1015750'],
#  ['3402367'],
#  ['3952107'],
#  ['4203551'],
#  ['105782'],
#  ['12607349'],
#  ['2745282'],
#  ['13073542'],
#  ['4334886'],
#  ['2026466'],
#  ['6907454'],
#  ['8946757'],
#  ['1755816'],
#  ['5952380'],
#  ['6993'],
#  ['765292'],
#  ['6203'],
#  ['6222'],
#  ['108291'],
#  ['2133557'],
#  ['146508'],
#  ['4034273'],
#  ['6206971'],
#  ['5271873'],
#  ['20300885'],
#  ['557974'],
#  ['5452411'],
#  ['1710748'],
#  ['117982'],
#  ['12551938'],
#  ['49597893'],
#  ['24606279'],
#  ['1615119'],
#  ['9354487'],
#  ['40481594'],
#  ['2571457'],
#  ['65967'],
#  ['24362158'],
#  ['1278272'],
#  ['27117126'],
#  ['6033817'],
#  ['9984'],
#  ['24954061'],
#  ['2799278'],
#  ['5589805'],
#  ['196550'],
#  ['28308729'],
#  ['2835838'],
#  ['1653144'],
#  ['4894864'],
#  ['479385'],
#  ['28378612'],
#  ['48365721'],
#  ['5309477'],
#  ['16389235'],
#  ['21346749'],
#  ['1693533'],
#  ['1466247'],
#  ['543083'],
#  ['13249'],
#  ['2203032'],
#  ['8075081'],
#  ['3984805'],
#  ['22718385'],
#  ['1004493'],
#  ['6136'],
#  ['11620352'],
#  ['386817'],
#  ['8758'],
#  ['50757'],
#  ['143757'],
#  ['20067483'],
#  ['1799671'],
#  ['16529284'],
#  ['2590526'],
#  ['13057363'],
#  ['336018'],
#  ['33639192'],
#  ['540571'],
#  ['791428'],
#  ['6913247'],
#  ['22377272'],
#  ['2871115'],
#  ['2355371'],
#  ['2455522'],
#  ['4965467'],
#  ['17096781'],
#  ['17516600'],
#  ['2260636'],
#  ['4067146'],
#  ['2598348'],
#  ['1825457'],
#  ['6588412'],
#  ['5299946'],
#  ['6600239'],
#  ['16572603'],
#  ['19248089'],
#  ['2985817'],
#  ['4571461'],
#  ['586190'],
#  ['2858063'],
#  ['8004531'],
#  ['1023571'],
#  ['16102568'],
#  ['3528986'],
#  ['3382615'],
#  ['8483601'],
#  ['11320334'],
#  ['1758012'],
#  ['4658463'],
#  ['1097683'],
#  ['6379583'],
#  ['1562663'],
#  ['9232885'],
#  ['3056059'],
#  ['11760794'],
#  ['8482648'],
#  ['4215024'],
#  ['133606'],
#  ['254096'],
#  ['1905161'],
#  ['18143228'],
#  ['2642132'],
#  ['8672476'],
#  ['1093059'],
#  ['2111315'],
#  ['9736'],
#  ['2054448'],
#  ['7348371'],
#  ['28941170'],
#  ['240504'],
#  ['2217157'],
#  ['1443957'],
#  ['9087229'],
#  ['12376839'],
#  ['11477652'],
#  ['1706993'],
#  ['222024'],
#  ['4928927'],
#  ['11654626'],
#  ['1454785'],
#  ['52724419'],
#  ['3906165'],
#  ['742103'],
#  ['3834960'],
#  ['13153055'],
#  ['5438586'],
#  ['7347052'],
#  ['135636'],
#  ['7798196'],
#  ['47597'],
#  ['7026027'],
#  ['6107295'],
#  ['6434138'],
#  ['1836077'],
#  ['3175306'],
#  ['1840470'],
#  ['1923830'],
#  ['22358802'],
#  ['640725'],
#  ['20851684'],
#  ['5005311'],
#  ['1634771']]

# %%
#We create an empty list to populate with all the ids and retrieve each url to find their number like above
list_ids_2 = []

#We create an empty list to populate with all the ids and retrieve each url to find their number like above
for soup in trial_2:
    url = soup
    page = requests.get(url)
    soup_2 = Soup(page.content, "html.parser")
    id_profile = soup_2.select("div.spans5 a.button")[0]["href"]
    id_finale = re.findall(r"(?<=content=)\d*", id_profile)
    list_ids_2.append(id_finale)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-39-73ec21f70865> in <module>
#       7     page = requests.get(url)
#       8     soup_2 = Soup(page.content, "html.parser")
# ----> 9     id_profile = soup_2.select("div.spans5 a.button")[0]["href"]
#      10     id_finale = re.findall(r"(?<=content=)\d*", id_profile)
#      11     list_ids_2.append(id_finale)
#
# IndexError: list index out of range

# %%
list_ids_2

# %%
trial_3
# Out:
# ['https://www.strava.com/pros/csantossantos',
#  'https://www.strava.com/pros/msarreau',
#  'https://www.strava.com/pros/jsarrou',
#  'https://www.strava.com/pros/yukisato',
#  'https://www.strava.com/pros/jsauvagnargues',
#  'https://www.strava.com/pros/mike_sayenko',
#  'https://www.strava.com/pros/dakota_schaeffer',
#  'https://www.strava.com/pros/timo-sch%C3%A4fer-12453572',
#  'https://www.strava.com/pros/mschppi',
#  'https://www.strava.com/pros/michaelschaer',
#  'https://www.strava.com/pros/jscheiding',
#  'https://www.strava.com/pros/jschelb',
#  'https://www.strava.com/pros/pschelling',
#  'https://www.strava.com/pros/simon-schempp-9443105',
#  'https://www.strava.com/pros/katie-schide-9517070',
#  'https://www.strava.com/pros/rschildknecht',
#  'https://www.strava.com/pros/andreas_schillinger',
#  'https://www.strava.com/pros/johannes_schinnagel',
#  'https://www.strava.com/pros/jschlarb',
#  'https://www.strava.com/pros/fabien_schmidt',
#  'https://www.strava.com/pros/mads_schmidt',
#  'https://www.strava.com/pros/paul-schmidt-hellinger-7785469',
#  'https://www.strava.com/pros/morgan_schmitt',
#  'https://www.strava.com/pros/mschnapka',
#  'https://www.strava.com/pros/joab_schneiter',
#  'https://www.strava.com/pros/nschneitter',
#  'https://www.strava.com/pros/amy-schnittger-7574879',
#  'https://www.strava.com/pros/dschnherr',
#  'https://www.strava.com/pros/fschormair',
#  'https://www.strava.com/pros/cschwendter',
#  'https://www.strava.com/pros/nick_schultz',
#  'https://www.strava.com/pros/marc_schulze',
#  'https://www.strava.com/pros/schurter',
#  'https://www.strava.com/pros/simone_schwarz',
#  'https://www.strava.com/pros/karissa_schweizer',
#  'https://www.strava.com/pros/mscotney',
#  'https://www.strava.com/pros/mark-scott-615474',
#  'https://www.strava.com/pros/marc-scott-22362281',
#  'https://www.strava.com/pros/aaron-scott-2461157',
#  'https://www.strava.com/pros/drew_scott',
#  'https://www.strava.com/pros/roberto-scottini-2644559',
#  'https://www.strava.com/pros/stephen_scullion',
#  'https://www.strava.com/pros/patrickseabase',
#  'https://www.strava.com/pros/bygollymolly',
#  'https://www.strava.com/pros/rudi-selig-26565115',
#  'https://www.strava.com/pros/simon_sellier',
#  'https://www.strava.com/pros/manuel-senni-26595296',
#  'https://www.strava.com/pros/eric-senseman-7264139',
#  'https://www.strava.com/pros/eduardo-sep%C3%BAlveda-13194699',
#  'https://www.strava.com/pros/louserafini',
#  'https://www.strava.com/pros/gserranorodriguez',
#  'https://www.strava.com/pros/aserrieres',
#  'https://www.strava.com/pros/pserry',
#  'https://www.strava.com/pros/nsessler',
#  'https://www.strava.com/pros/isharman',
#  'https://www.strava.com/pros/amelia_sharpe',
#  'https://www.strava.com/pros/vshatrov',
#  'https://www.strava.com/pros/lucy_shaw',
#  'https://www.strava.com/pros/bshebest',
#  'https://www.strava.com/pros/michael-sheehan-5327119',
#  'https://www.strava.com/pros/matthew_sheeks',
#  'https://www.strava.com/pros/csherriffs',
#  'https://www.strava.com/pros/hiroki_shimura',
#  'https://www.strava.com/pros/jarrodshoemaker',
#  'https://www.strava.com/pros/jesseshotland',
#  'https://www.strava.com/pros/brian-shrader-8382284',
#  'https://www.strava.com/pros/mamadou_1992',
#  'https://www.strava.com/pros/msides',
#  'https://www.strava.com/pros/msieberg',
#  'https://www.strava.com/pros/jsiegle',
#  'https://www.strava.com/pros/psimion',
#  'https://www.strava.com/pros/ben_simmons',
#  'https://www.strava.com/pros/quinn_simmons',
#  'https://www.strava.com/pros/simon_julien',
#  'https://www.strava.com/pros/jenny-simpson-27885667',
#  'https://www.strava.com/pros/george-simpson-1041508',
#  'https://www.strava.com/pros/rsinkeldam',
#  'https://www.strava.com/pros/esiskevicius',
#  'https://www.strava.com/pros/jake_sitler',
#  'https://www.strava.com/pros/psivakov',
#  'https://www.strava.com/pros/kskjerping',
#  'https://www.strava.com/pros/vinjar_skogsholm',
#  'https://www.strava.com/pros/rslik',
#  'https://www.strava.com/pros/islik',
#  'https://www.strava.com/pros/csmall',
#  'https://www.strava.com/pros/willie_smit',
#  'https://www.strava.com/pros/smith_haley',
#  'https://www.strava.com/pros/abi-smith-6109502',
#  'https://www.strava.com/pros/sean_smith',
#  'https://www.strava.com/pros/dions',
#  'https://www.strava.com/pros/jason-smith-205886',
#  'https://www.strava.com/pros/jsoek',
#  'https://www.strava.com/pros/dsoete',
#  'https://www.strava.com/pros/tom-soladay-1294349',
#  'https://www.strava.com/pros/marcsoler',
#  'https://www.strava.com/pros/julie_solvang',
#  'https://www.strava.com/pros/bsonntag',
#  'https://www.strava.com/pros/rodrigosouzaofficial',
#  'https://www.strava.com/pros/allanspangler',
#  'https://www.strava.com/pros/jsparls',
#  'https://www.strava.com/pros/kate-spencer-6822117',
#  'https://www.strava.com/pros/esperger',
#  'https://www.strava.com/pros/amanda_spratt',
#  'https://www.strava.com/pros/tsprengers',
#  'https://www.strava.com/pros/amy-sproston-7910905',
#  'https://www.strava.com/pros/bstlawrence',
#  'https://www.strava.com/pros/stannard_ian',
#  'https://www.strava.com/pros/julien_stassen',
#  'https://www.strava.com/pros/cstastny',
#  'https://www.strava.com/pros/mex_',
#  'https://www.strava.com/pros/ssteels',
#  'https://www.strava.com/pros/jsteimle',
#  'https://www.strava.com/pros/orvars',
#  'https://www.strava.com/pros/csteinhammer',
#  'https://www.strava.com/pros/katharina-steinruck-53369340',
#  'https://www.strava.com/pros/jimstemper',
#  'https://www.strava.com/pros/rstnuit',
#  'https://www.strava.com/pros/karla_stepanova',
#  'https://www.strava.com/pros/kerstinstephan',
#  'https://www.strava.com/pros/stephens_lauren',
#  'https://www.strava.com/pros/ssterbini',
#  'https://www.strava.com/pros/jeffreystern',
#  'https://www.strava.com/pros/pstetina',
#  'https://www.strava.com/pros/morabito_steve',
#  'https://www.strava.com/pros/swarior',
#  'https://www.strava.com/pros/christofer_stevenson',
#  'https://www.strava.com/pros/tom-stewart-2262698',
#  'https://www.strava.com/pros/jake-stewart-17096447',
#  'https://www.strava.com/pros/katherine-stewart-jones-42373130',
#  'https://www.strava.com/pros/tylerstites',
#  'https://www.strava.com/pros/andreas_stokbro',
#  'https://www.strava.com/pros/conrad_stoltz',
#  'https://www.strava.com/pros/stone_mike',
#  'https://www.strava.com/pros/casper-stornes-11143315',
#  'https://www.strava.com/pros/mstrandemo',
#  'https://www.strava.com/pros/andreas_straner',
#  'https://www.strava.com/pros/mstreb',
#  'https://www.strava.com/pros/annazm_stricker',
#  'https://www.strava.com/pros/colin_strickland',
#  'https://www.strava.com/pros/chris-stuart-442498',
#  'https://www.strava.com/pros/sstultiens',
#  'https://www.strava.com/pros/ges0045',
#  'https://www.strava.com/pros/sturgess_colin',
#  'https://www.strava.com/pros/ssttzel',
#  'https://www.strava.com/pros/jstuyven',
#  'https://www.strava.com/pros/esujew',
#  'https://www.strava.com/pros/diana-sujew-54332354',
#  'https://www.strava.com/pros/bsulzberger',
#  'https://www.strava.com/pros/dsummerhill',
#  'https://www.strava.com/pros/dsunderland',
#  'https://www.strava.com/pros/mike_sunseri',
#  'https://www.strava.com/pros/jaume_sureda',
#  'https://www.strava.com/pros/lsemilch',
#  'https://www.strava.com/pros/jstterlin',
#  'https://www.strava.com/pros/chris-sutton-3831552',
#  'https://www.strava.com/pros/sutton_joe',
#  'https://www.strava.com/pros/yuzup',
#  'https://www.strava.com/pros/psvarc',
#  'https://www.strava.com/pros/lsweeck',
#  'https://www.strava.com/pros/kswenson',
#  'https://www.strava.com/pros/connor_swift',
#  'https://www.strava.com/pros/ben_swift',
#  'https://www.strava.com/pros/kswirbul',
#  'https://www.strava.com/pros/wsybrandy',
#  'https://www.strava.com/pros/symonds_joe',
#  'https://www.strava.com/pros/jeff_symonds',
#  'https://www.strava.com/pros/ryu_takaku',
#  'https://www.strava.com/pros/ktakeyama',
#  'https://www.strava.com/pros/hiroyasu_tanaka',
#  'https://www.strava.com/pros/ctanfield',
#  'https://www.strava.com/pros/harry-tanfield-1138679',
#  'https://www.strava.com/pros/audrey-tanguy-38392283',
#  'https://www.strava.com/pros/btankink',
#  'https://www.strava.com/pros/jake_tanner',
#  'https://www.strava.com/pros/natalie-tanner-23547111',
#  'https://www.strava.com/pros/kyle-taylor-756805',
#  'https://www.strava.com/pros/kellyn_taylor',
#  'https://www.strava.com/pros/ctaylor',
#  'https://www.strava.com/pros/ashley-taylor-23895742',
#  'https://www.strava.com/pros/steddergreen',
#  'https://www.strava.com/pros/matthew-teggart-6390566',
#  'https://www.strava.com/pros/laurenstendam',
#  'https://www.strava.com/pros/mike_terpstra',
#  'https://www.strava.com/pros/nterpstra',
#  'https://www.strava.com/pros/tommy-test4-12413962',
#  'https://www.strava.com/pros/amtetrick',
#  'https://www.strava.com/pros/mteuber',
#  'https://www.strava.com/pros/mike_teunissen',
#  'https://www.strava.com/pros/iteutenberg',
#  'https://www.strava.com/pros/ttheuer',
#  'https://www.strava.com/pros/etheuns',
#  'https://www.strava.com/pros/thevenotg',
#  'https://www.strava.com/pros/jeff_thies',
#  'https://www.strava.com/pros/gerben_thijssen',
#  'https://www.strava.com/pros/benjamin-thomas-1700745',
#  'https://www.strava.com/pros/thomas_leah',
#  'https://www.strava.com/pros/jesse_thomas',
#  'https://www.strava.com/pros/thomson_jay',
#  'https://www.strava.com/pros/thomson_jacob',
#  'https://www.strava.com/pros/lthorvilson',
#  'https://www.strava.com/pros/max_totto',
#  'https://www.strava.com/pros/thums',
#  'https://www.strava.com/pros/scott_thwaites1',
#  'https://www.strava.com/pros/stilford',
#  'https://www.strava.com/pros/albert-timmer-5977143',
#  'https://www.strava.com/pros/brian_tinder',
#  'https://www.strava.com/pros/ericatingey',
#  'https://www.strava.com/pros/jacob_tipper',
#  'https://www.strava.com/pros/mtisseyre',
#  'https://www.strava.com/pros/mtizza',
#  'https://www.strava.com/pros/maarten-tjallingii-7171877',
#  'https://www.strava.com/pros/atolhoek',
#  'https://www.strava.com/pros/tim_tollefson',
#  'https://www.strava.com/pros/atomsich',
#  'https://www.strava.com/pros/alessandro_tonelli',
#  'https://www.strava.com/pros/ian-torchia-15565404',
#  'https://www.strava.com/pros/david_torrence',
#  'https://www.strava.com/pros/itorrence',
#  'https://www.strava.com/pros/pablotorres87',
#  'https://www.strava.com/pros/lauren_totten',
#  'https://www.strava.com/pros/totten_seth',
#  'https://www.strava.com/pros/dtouz',
#  'https://www.strava.com/pros/rory_townsend',
#  'https://www.strava.com/pros/mroeger',
#  'https://www.strava.com/pros/julientrarieux',
#  'https://www.strava.com/pros/htrettwer',
#  'https://www.strava.com/pros/coberman',
#  'https://www.strava.com/pros/zuzka',
#  'https://www.strava.com/pros/ben_true',
#  'https://www.strava.com/pros/sarah_true',
#  'https://www.strava.com/pros/tryoen_jonathan',
#  'https://www.strava.com/pros/tori_tsolis',
#  'https://www.strava.com/pros/serge_tsvetkov',
#  'https://www.strava.com/pros/atuliamuk',
#  'https://www.strava.com/pros/dturek',
#  'https://www.strava.com/pros/ben-turner-32660500',
#  'https://www.strava.com/pros/mtusveld',
#  'https://www.strava.com/pros/stephanie_twell',
#  'https://www.strava.com/pros/chris_uberti',
#  'https://www.strava.com/pros/kuchima',
#  'https://www.strava.com/pros/ruy_ueda',
#  'https://www.strava.com/pros/iupdike',
#  'https://www.strava.com/pros/ruran',
#  'https://www.strava.com/pros/arto_vainionp',
#  'https://www.strava.com/pros/lvainionp',
#  'https://www.strava.com/pros/pvakoc',
#  'https://www.strava.com/pros/mvalgren',
#  'https://www.strava.com/pros/boris_valle',
#  'https://www.strava.com/pros/wvanaert',
#  'https://www.strava.com/pros/tvanasbroeck',
#  'https://www.strava.com/pros/gvanavermaet',
#  'https://www.strava.com/pros/dvanbaarle',
#  'https://www.strava.com/pros/timberkel',
#  'https://www.strava.com/pros/janvanberkel',
#  'https://www.strava.com/pros/fvandewyngard',
#  'https://www.strava.com/pros/tuur_vandenbergh',
#  'https://www.strava.com/pros/kvandensteen',
#  'https://www.strava.com/pros/nvanderlijke',
#  'https://www.strava.com/pros/neilvanderploeg',
#  'https://www.strava.com/pros/david_vanderpoel',
#  'https://www.strava.com/pros/mathieu_vanderpoel',
#  'https://www.strava.com/pros/toshvds',
#  'https://www.strava.com/pros/ellen_vandijk',
#  'https://www.strava.com/pros/jordi_vandingenen',
#  'https://www.strava.com/pros/jos_vanemden',
#  'https://www.strava.com/pros/evanempel',
#  'https://www.strava.com/pros/tvangarderen',
#  'https://www.strava.com/pros/brianvangoethem',
#  'https://www.strava.com/pros/mathias_vangompel',
#  'https://www.strava.com/pros/nathan_vanhooydonck',
#  'https://www.strava.com/pros/rudi_vanhouts',
#  'https://www.strava.com/pros/rvanijzendoorn',
#  'https://www.strava.com/pros/gvankeirsbulck',
#  'https://www.strava.com/pros/cvankessel',
#  'https://www.strava.com/pros/jef_vanmeirhaeghe',
#  'https://www.strava.com/pros/kvin_vanmelsen',
#  'https://www.strava.com/pros/aaron-van-poucke-7967844',
#  'https://www.strava.com/pros/marten_vanriel',
#  'https://www.strava.com/pros/michael_vanstaeyen',
#  'https://www.strava.com/pros/bryony-van-velzen-1088553',
#  'https://www.strava.com/pros/avanvleuten',
#  'https://www.strava.com/pros/ivanwilder',
#  'https://www.strava.com/pros/dvanwinden',
#  'https://www.strava.com/pros/kenneth_vanbilsen',
#  'https://www.strava.com/pros/wvandegaer',
#  'https://www.strava.com/pros/hvandenabeele',
#  'https://www.strava.com/pros/ward_vanhoof',
#  'https://www.strava.com/pros/houckie',
#  'https://www.strava.com/pros/mvanthourenhout',
#  'https://www.strava.com/pros/dvanthourenhout',
#  'https://www.strava.com/pros/cvardaros',
#  'https://www.strava.com/pros/cvargo',
#  'https://www.strava.com/pros/alicia_shay',
#  'https://www.strava.com/pros/afvarner',
#  'https://www.strava.com/pros/jip_vastenburg',
#  'https://www.strava.com/pros/jan-vastl-maloja-pushbikers-44644405',
#  'https://www.strava.com/pros/svaughnjr',
#  'https://www.strava.com/pros/jveikkanen',
#  'https://www.strava.com/pros/simone_velasco',
#  'https://www.strava.com/pros/jacoventer',
#  'https://www.strava.com/pros/fran_v',
#  'https://www.strava.com/pros/ismaelventura',
#  'https://www.strava.com/pros/cventurini',
#  'https://www.strava.com/pros/luke_verburg',
#  'https://www.strava.com/pros/overgaerde',
#  'https://www.strava.com/pros/suzanne_verhoeven',
#  'https://www.strava.com/pros/florian-vermeersch-9421925',
#  'https://www.strava.com/pros/gvermeersch',
#  'https://www.strava.com/pros/alexeyvermeulen',
#  'https://www.strava.com/pros/emiel_vermeulen',
#  'https://www.strava.com/pros/ethan_vernon',
#  'https://www.strava.com/pros/cverona',
#  'https://www.strava.com/pros/verschaevevik',
#  'https://www.strava.com/pros/nverschelden',
#  'https://www.strava.com/pros/katrien_verstuyft',
#  'https://www.strava.com/pros/lvervaeke',
#  'https://www.strava.com/pros/averwilst',
#  'https://www.strava.com/pros/lverzbicas',
#  'https://www.strava.com/pros/mvezina',
#  'https://www.strava.com/pros/arthur_dg',
#  'https://www.strava.com/pros/vilela_ricardo',
#  'https://www.strava.com/pros/pvillagonzlez',
#  'https://www.strava.com/pros/pablo-villalobos-6263915',
#  'https://www.strava.com/pros/davide_villella',
#  'https://www.strava.com/pros/thiago_vinhal',
#  'https://www.strava.com/pros/avisokay',
#  'https://www.strava.com/pros/fvogel',
#  'https://www.strava.com/pros/nils_voigt',
#  'https://www.strava.com/pros/rvonberg',
#  'https://www.strava.com/pros/mariannevosofficial',
#  'https://www.strava.com/pros/vos_andrew',
#  'https://www.strava.com/pros/pvo',
#  'https://www.strava.com/pros/vvrhovnik',
#  'https://www.strava.com/pros/diosbasado',
#  'https://www.strava.com/pros/apika',
#  'https://www.strava.com/pros/lennie_waite',
#  'https://www.strava.com/pros/nwaite',
#  'https://www.strava.com/pros/jwale',
#  'https://www.strava.com/pros/joey-walker-2569508',
#  'https://www.strava.com/pros/max-walker-5627020',
#  'https://www.strava.com/pros/jelle-wallays-16345356',
#  'https://www.strava.com/pros/dawallmann',
#  'https://www.strava.com/pros/walmsleyruns',
#  'https://www.strava.com/pros/mwalscheid',
#  'https://www.strava.com/pros/orlawalsh',
#  'https://www.strava.com/pros/philipp_w',
#  'https://www.strava.com/pros/redster',
#  'https://www.strava.com/pros/julien-wanders-60504051',
#  'https://www.strava.com/pros/liyang_w',
#  'https://www.strava.com/pros/yiou_wang',
#  'https://www.strava.com/pros/lwarbasse',
#  'https://www.strava.com/pros/caine_warburton',
#  'https://www.strava.com/pros/michael-ward-1307600',
#  'https://www.strava.com/pros/rabwardell',
#  'https://www.strava.com/pros/mwardian',
#  'https://www.strava.com/pros/jordi_warlop',
#  'https://www.strava.com/pros/kyle_warner',
#  'https://www.strava.com/pros/antoine_warnier',
#  'https://www.strava.com/pros/ewatenpaugh',
#  'https://www.strava.com/pros/rob-watson-9552437',
#  'https://www.strava.com/pros/cole-watson-10078792',
#  'https://www.strava.com/pros/steveway',
#  'https://www.strava.com/pros/lindsay-webster-16169087',
#  'https://www.strava.com/pros/robbywebster',
#  'https://www.strava.com/pros/matthewwebster',
#  'https://www.strava.com/pros/sweiss',
#  'https://www.strava.com/pros/twellens',
#  'https://www.strava.com/pros/brooke_wells',
#  'https://www.strava.com/pros/todd_wells',
#  'https://www.strava.com/pros/sam_welsford',
#  'https://www.strava.com/pros/stephan_wenk',
#  'https://www.strava.com/pros/kerry_werner',
#  'https://www.strava.com/pros/mwernsdrfer',
#  'https://www.strava.com/pros/owenwesterhout',
#  'https://www.strava.com/pros/shaky_shake',
#  'https://www.strava.com/pros/jen_whalen',
#  'https://www.strava.com/pros/jwheeler',
#  'https://www.strava.com/pros/half-wheeler-1401291',
#  'https://www.strava.com/pros/joey-whelan-10349357',
#  'https://www.strava.com/pros/jimmy-whelan-3356275',
#  'https://www.strava.com/pros/brad_white',
#  'https://www.strava.com/pros/curtisjwhite',
#  'https://www.strava.com/pros/nwhitman',
#  'https://www.strava.com/pros/runwietecha',
#  'https://www.strava.com/pros/hiruni_wijayaratne',
#  'https://www.strava.com/pros/wild_kirsten',
#  'https://www.strava.com/pros/awild',
#  'https://www.strava.com/pros/tayler_wiles',
#  'https://www.strava.com/pros/twileyt',
#  'https://www.strava.com/pros/pete-williams-1975572',
#  'https://www.strava.com/pros/wcory',
#  'https://www.strava.com/pros/c1williamsau',
#  'https://www.strava.com/pros/justin-williams-207266',
#  'https://www.strava.com/pros/georgia_williams',
#  'https://www.strava.com/pros/lexb0x',
#  'https://www.strava.com/pros/williams_lily',
#  'https://www.strava.com/pros/martin-williams-2913779',
#  'https://www.strava.com/pros/sam-williams-neo-pro-coaching-784417',
#  'https://www.strava.com/pros/bw_tri',
#  'https://www.strava.com/pros/nick-willis-17875888',
#  'https://www.strava.com/pros/jack-wilson-661964',
#  'https://www.strava.com/pros/ruth_winder',
#  'https://www.strava.com/pros/cwinsor',
#  'https://www.strava.com/pros/lwisniowski',
#  'https://www.strava.com/pros/kwithrow',
#  'https://www.strava.com/pros/natasha-wodak-7814602',
#  'https://www.strava.com/pros/chloewoodruff',
#  'https://www.strava.com/pros/tjwoodruff',
#  'https://www.strava.com/pros/ryan_woods',
#  'https://www.strava.com/pros/mike-woods-425147',
#  'https://www.strava.com/pros/wouterse',
#  'https://www.strava.com/pros/twren',
#  'https://www.strava.com/pros/fred-wright-25495602',
#  'https://www.strava.com/pros/bw-s',
#  'https://www.strava.com/pros/twurtele',
#  'https://www.strava.com/pros/hwurtele',
#  'https://www.strava.com/pros/shelven',
#  'https://www.strava.com/pros/judith_wyder',
#  'https://www.strava.com/pros/helen_wyman',
#  'https://www.strava.com/pros/mwynants',
#  'https://www.strava.com/pros/henry_wynne',
#  'https://www.strava.com/pros/danilo_wyss',
#  'https://www.strava.com/pros/yadgarov',
#  'https://www.strava.com/pros/devonyanko',
#  'https://www.strava.com/pros/simon_yates',
#  'https://www.strava.com/pros/jesse_yates',
#  'https://www.strava.com/pros/adamyates7',
#  'https://www.strava.com/pros/kris-yip-10932800',
#  'https://www.strava.com/pros/shotayoda',
#  'https://www.strava.com/pros/kohei-yokotsuka',
#  'https://www.strava.com/pros/minehiroyokoyama',
#  'https://www.strava.com/pros/york_brandon',
#  'https://www.strava.com/pros/yoshioka_naoya',
#  'https://www.strava.com/pros/clayton-young-23295862',
#  'https://www.strava.com/pros/zabalaj',
#  'https://www.strava.com/pros/rick_zabel',
#  'https://www.strava.com/pros/katie-zaferes-20078016',
#  'https://www.strava.com/pros/izakarin',
#  'https://www.strava.com/pros/czambrano',
#  'https://www.strava.com/pros/joannazeiger',
#  'https://www.strava.com/pros/andrey-zeits-13393892',
#  'https://www.strava.com/pros/rzepuntke',
#  'https://www.strava.com/pros/uzigart',
#  'https://www.strava.com/pros/maikel-zijlaard-10087367',
#  'https://www.strava.com/pros/georg_zimmermann',
#  'https://www.strava.com/pros/nzubenko',
#  'https://www.strava.com/pros/benzwiehoff',
#  'https://www.strava.com/pros/szwiza',
#  'https://www.strava.com/pros/mbelanger-barrette',
#  'https://www.strava.com/pros/jack_rees',
#  'https://www.strava.com/pros/dan_bigham',
#  'https://www.strava.com/pros/gilbert_jerome',
#  'https://www.strava.com/pros/martinhaugo',
#  'https://www.strava.com/pros/kouta_murayama',
#  'https://www.strava.com/pros/amityvil',
#  'https://www.strava.com/pros/john-ellis-%F0%9F%8C%AA-t8-run-1489377',
#  'https://www.strava.com/pros/gledhill_leon']

# %%
list_ids_3 = []

#We create an empty list to populate with all the ids and retrieve each url to find their number like above
for soup in trial_3:
    url = soup
    page = requests.get(url)
    soup_1 = Soup(page.content, "html.parser")
    id_profile = soup_1.select("div.spans5 a.button")[0]["href"]
    id_finale = re.findall(r"(?<=content=)\d*", id_profile)
    list_ids_3.append(id_finale)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-678809f188d8> in <module>
#       6     page = requests.get(url)
#       7     soup_1 = Soup(page.content, "html.parser")
# ----> 8     id_profile = soup_1.select("div.spans5 a.button")[0]["href"]
#       9     id_finale = re.findall(r"(?<=content=)\d*", id_profile)
#      10     list_ids_3.append(id_finale)
#
# IndexError: list index out of range

# %%
list_ids_3

# %% [markdown]
# #### Once we have extracted the four parts of the ids, we put them all together in a unique list and find their entire ids.

# %%
top_profiles = top_profiles[0:1956]
len(top_profiles)
# Out:
# 1956

# %%
#We create an empty list to populate with all the ids and retrieve each url to find their number like above
"""for soup in absolute_url:
    url = soup
    page = requests.get(url)
    soup_1 = Soup(page.content, "html.parser")
    id_profile = soup_1.select("div.spans5 a.button")[0]["href"]
    id_finale = re.findall(r"(?<=content=)\d*", id_profile)
    list_ids.append(id_finale)"""

# %%
len(flattened_list_ids)
# Out:
# 1956

# %%
table_1 = pd.DataFrame({"Athlete Name": top_profiles, "IDs": flattened_list_ids})

# %%
names = table_1

# %%
names.to_csv("Names_IDs.csv")
