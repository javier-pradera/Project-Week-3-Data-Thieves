# %%
# import libraries
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../../Sources/athletes.csv", sep="|")
df
# Out:
#               id                name nationality     sex date_of_birth  \
# 0      736041664      A Jesus Garcia         ESP    male    1969-10-17
# 1      532037425          A Lam Shin         KOR  female    1986-09-23
# 2      435962603         Aaron Brown         CAN    male    1992-05-27
# 3      521041435          Aaron Cook         MDA    male    1991-01-02
# 4       33922579          Aaron Gate         NZL    male    1990-11-26
# ...          ...                 ...         ...     ...           ...
# 11533  265605954  Zurian Hechavarria         CUB  female    1995-08-10
# 11534  214461847      Zuzana Hejnova         CZE  female    1986-12-19
# 11535   88361042             di Xiao         CHN    male    1991-05-14
# 11536  900065925   le Quoc Toan Tran         VIE    male    1989-04-05
# 11537  711404576      le Roux Hamman         RSA    male    1992-01-06
#
#        height  weight          sport  gold  silver  bronze  info
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11538 entries, 0 to 11537
# Data columns (total 12 columns):
# id               11538 non-null object
# name             11406 non-null object
# nationality      11406 non-null object
# sex              11406 non-null object
# date_of_birth    11406 non-null object
# height           11077 non-null float64
# weight           10755 non-null float64
# sport            11406 non-null object
# gold             11406 non-null float64
# silver           11406 non-null float64
# bronze           11406 non-null float64
# info             0 non-null float64
# dtypes: float64(6), object(6)
# memory usage: 1.1+ MB

# %%
df = df.drop('info', axis= 1)

# %%
# Make a list of all competitors of cycling and athletics
new_list =[]
for athlete in range(len(df)):
    if (df['sport'][athlete] == 'cycling')| (df['sport'][athlete] == 'athletics'):
        new_list.append([df['id'][athlete], df['name'][athlete],df['nationality'][athlete],
                         df['sex'][athlete],df['date_of_birth'][athlete],df['height'][athlete],df['weight'][athlete],
                        df['sport'][athlete],df['gold'][athlete],df['silver'][athlete],df['bronze'][athlete]])
        
new_list
# Out:
# [['736041664',
#   'A Jesus Garcia',
#   'ESP',
#   'male',
#   '1969-10-17',
#   1.72,
#   64.0,
#   'athletics',
#   0.0,
#   0.0,
#   0.0],
#  ['435962603',
#   'Aaron Brown',
#   'CAN',
#   'male',
#   '1992-05-27',
#   1.98,
#   79.0,
#   'athletics',
#   0.0,
#   0.0,
#   1.0],
#  ['33922579',
#   'Aaron Gate',
#   'NZL',
#   'male',
#   '1990-11-26',
#   1.81,
#   71.0,
#   'cycling',
#   0.0,
#   0.0,
#   0.0],
#  ['87689776',
#   'Aauri Lorena Bokesa',
#   'ESP',
#   'female',
#   '1988-12-14',
#   1.8,
#   62.0,
#   'athletics',
#   0.0,
#   0.0,
#   0.0],
#  ['997877719',
#   'Ababel Yeshaneh',
#   'ETH',
#   'female',
#   '1991-07-22',
#   1.65,
#   54.0,
#   'athletics',
#   0.0,
#   0.0,
#   0.0],
#  ['343694681',
#   'Abadi Hadis',
#   'ETH',
#   'male',
#   '1997-11-06',
#   1.7,
#   63.0,
#   'athletics',
#   0.0,
#   0.0,
#   0.0],
#  ['591319906',
#   'Abbas Abubakar Abbas',
#   'BRN',
#   'male',
#   '1996-05-17',
#   1.75,
#   66.0,
#   'athletics',
#   0.0,
# ...

# %%
# make dataframa again
# column names , df.columns
columns = ['id', 'name', 'nationality', 'sex', 'date_of_birth', 'height', 'weight',
       'sport', 'gold', 'silver', 'bronze']

# create df
athletics_and_cycling = pd.DataFrame(new_list, columns= columns)
athletics_and_cycling
# Out:
#              id                 name nationality     sex date_of_birth  \
# 0     736041664       A Jesus Garcia         ESP    male    1969-10-17
# 1     435962603          Aaron Brown         CAN    male    1992-05-27
# 2      33922579           Aaron Gate         NZL    male    1990-11-26
# 3      87689776  Aauri Lorena Bokesa         ESP  female    1988-12-14
# 4     997877719      Ababel Yeshaneh         ETH  female    1991-07-22
# ...         ...                  ...         ...     ...           ...
# 2863  724419150        Zouhair Aouad         BRN    male    1989-04-07
# 2864  999437858       Zsofia Erdelyi         HUN  female    1987-12-10
# 2865  265605954   Zurian Hechavarria         CUB  female    1995-08-10
# 2866  214461847       Zuzana Hejnova         CZE  female    1986-12-19
# 2867  711404576       le Roux Hamman         RSA    male    1992-01-06
#
#       height  weight      sport  gold  silver  bronze
# 0       1.72    64.0  athletics   0.0     0.0     0.0
# ...

# %%
# data cleaning
athletics_and_cycling.columns
# Out:
# Index(['id', 'name', 'nationality', 'sex', 'date_of_birth', 'height', 'weight',
#        'sport', 'gold', 'silver', 'bronze'],
#       dtype='object')

# %%
# data cleaning
athletics_and_cycling.reset_index(drop=True, inplace=True)
athletics_and_cycling
# Out:
#              id                 name nationality     sex date_of_birth  \
# 0     736041664       A Jesus Garcia         ESP    male    1969-10-17
# 1     435962603          Aaron Brown         CAN    male    1992-05-27
# 2      33922579           Aaron Gate         NZL    male    1990-11-26
# 3      87689776  Aauri Lorena Bokesa         ESP  female    1988-12-14
# 4     997877719      Ababel Yeshaneh         ETH  female    1991-07-22
# ...         ...                  ...         ...     ...           ...
# 2863  724419150        Zouhair Aouad         BRN    male    1989-04-07
# 2864  999437858       Zsofia Erdelyi         HUN  female    1987-12-10
# 2865  265605954   Zurian Hechavarria         CUB  female    1995-08-10
# 2866  214461847       Zuzana Hejnova         CZE  female    1986-12-19
# 2867  711404576       le Roux Hamman         RSA    male    1992-01-06
#
#       height  weight      sport  gold  silver  bronze
# 0       1.72    64.0  athletics   0.0     0.0     0.0
# ...

# %%
# dataframe wiht only athletics
ath_and_cy = athletics_and_cycling.copy()
athletics = ath_and_cy.loc[ath_and_cy['sport'] == 'athletics']
athletics
# Out:
#              id                 name nationality     sex date_of_birth  \
# 0     736041664       A Jesus Garcia         ESP    male    1969-10-17
# 1     435962603          Aaron Brown         CAN    male    1992-05-27
# 3      87689776  Aauri Lorena Bokesa         ESP  female    1988-12-14
# 4     997877719      Ababel Yeshaneh         ETH  female    1991-07-22
# 5     343694681          Abadi Hadis         ETH    male    1997-11-06
# ...         ...                  ...         ...     ...           ...
# 2863  724419150        Zouhair Aouad         BRN    male    1989-04-07
# 2864  999437858       Zsofia Erdelyi         HUN  female    1987-12-10
# 2865  265605954   Zurian Hechavarria         CUB  female    1995-08-10
# 2866  214461847       Zuzana Hejnova         CZE  female    1986-12-19
# 2867  711404576       le Roux Hamman         RSA    male    1992-01-06
#
#       height  weight      sport  gold  silver  bronze
# 0       1.72    64.0  athletics   0.0     0.0     0.0
# ...

# %%
# missing values for height, weight 166 and 162 respectively
athletics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2355 entries, 0 to 2867
# Data columns (total 11 columns):
# id               2355 non-null object
# name             2355 non-null object
# nationality      2355 non-null object
# sex              2355 non-null object
# date_of_birth    2355 non-null object
# height           2189 non-null float64
# weight           2193 non-null float64
# sport            2355 non-null object
# gold             2355 non-null float64
# silver           2355 non-null float64
# bronze           2355 non-null float64
# dtypes: float64(5), object(6)
# memory usage: 220.8+ KB

# %%
athletics['height'].fillna(athletics['height'].mean(),inplace=True)

# %%
athletics['weight'].fillna(athletics['weight'].mean(),inplace=True)

# %%
athletics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2355 entries, 0 to 2867
# Data columns (total 11 columns):
# id               2355 non-null object
# name             2355 non-null object
# nationality      2355 non-null object
# sex              2355 non-null object
# date_of_birth    2355 non-null object
# height           2355 non-null float64
# weight           2355 non-null float64
# sport            2355 non-null object
# gold             2355 non-null float64
# silver           2355 non-null float64
# bronze           2355 non-null float64
# dtypes: float64(5), object(6)
# memory usage: 220.8+ KB

# %% [markdown]
# # Cycling

# %%
# dataframe with only cyclists
cycling = ath_and_cy.loc[ath_and_cy['sport'] == 'cycling']
cycling
# Out:
#              id                   name nationality     sex date_of_birth  \
# 2      33922579             Aaron Gate         NZL    male    1990-11-26
# 15    285603057  Abderrahmane Mansouri         ALG    male    1995-01-13
# 30    184652432             Adam Yates         GBR    male    1992-08-07
# 38    664737236      Adrien Niyonshuti         RWA    male    1987-01-02
# 50    696999235            Ahmet Orken         TUR    male    1993-03-12
# ...         ...                    ...         ...     ...           ...
# 2838  116013385          Yuta Wakimoto         JPN    male    1989-03-21
# 2842  503085577           Zac Williams         NZL    male    1995-07-21
# 2849  538896901          Zdenek Stybar         CZE    male    1985-12-11
# 2852  989437678         Zhao Juan Meng         HKG  female    1989-12-14
# 2853  448660080              Zhen Wang         CHN    male    1989-06-26
#
#       height  weight    sport  gold  silver  bronze
# ...

# %%
cycling.info()
# ONly missing values for height,weight of 21 and 23 respectively
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 513 entries, 2 to 2853
# Data columns (total 11 columns):
# id               513 non-null object
# name             513 non-null object
# nationality      513 non-null object
# sex              513 non-null object
# date_of_birth    513 non-null object
# height           492 non-null float64
# weight           490 non-null float64
# sport            513 non-null object
# gold             513 non-null float64
# silver           513 non-null float64
# bronze           513 non-null float64
# dtypes: float64(5), object(6)
# memory usage: 48.1+ KB

# %%
cycling['height'].mean()
# Out:
# 1.7466260162601637

# %%
cycling.reset_index(drop=True, inplace=True)

# %%
cycling['height'][2]
# Out:
# 1.72

# %%
cycling['weight'].fillna(cycling['weight'].mean(),inplace=True)

# %%
cycling['height'].fillna(cycling['height'].mean(),inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513 entries, 0 to 512
# Data columns (total 11 columns):
# id               513 non-null object
# name             513 non-null object
# nationality      513 non-null object
# sex              513 non-null object
# date_of_birth    513 non-null object
# height           513 non-null float64
# weight           490 non-null float64
# sport            513 non-null object
# gold             513 non-null float64
# silver           513 non-null float64
# bronze           513 non-null float64
# dtypes: float64(5), object(6)
# memory usage: 44.2+ KB

# %%
cycling.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513 entries, 0 to 512
# Data columns (total 11 columns):
# id               513 non-null object
# name             513 non-null object
# nationality      513 non-null object
# sex              513 non-null object
# date_of_birth    513 non-null object
# height           513 non-null float64
# weight           513 non-null float64
# sport            513 non-null object
# gold             513 non-null float64
# silver           513 non-null float64
# bronze           513 non-null float64
# dtypes: float64(5), object(6)
# memory usage: 44.2+ KB

# %% [markdown]
# # Save dataframes as csv

# %%
# cycling.to_csv('../../Sources/ X.csv', sep=',')

cycling.to_csv('../../Sources/cyclist.csv', sep=",")

# %%
athletics.to_csv('../../Sources/athletics.csv', sep=",")

# %% [markdown]
# # Country distribution

# %%
athletics.groupby("nationality").sum()
# Out:
#              height  weight  gold  silver  bronze
# nationality
# AFG            3.40   123.0   0.0     0.0     0.0
# ALB            3.54   131.0   0.0     0.0     0.0
# ALG           26.02   948.0   0.0     2.0     0.0
# AND            1.78    62.0   0.0     0.0     0.0
# ANG            3.37   120.0   0.0     0.0     0.0
# ...             ...     ...   ...     ...     ...
# VIE            3.23   100.0   0.0     0.0     0.0
# VIN            3.51   120.0   0.0     0.0     0.0
# YEM            1.69    61.0   0.0     0.0     0.0
# ZAM            5.21   194.0   0.0     0.0     0.0
# ZIM           10.08   367.0   0.0     0.0     0.0
#
# [200 rows x 5 columns]

# %%
athletics.groupby("nationality").sum().sort_values("gold", ascending= False)
# Out:
#                  height       weight  gold  silver  bronze
# nationality
# USA          227.699502  9457.588691  25.0     9.0     9.0
# JAM           89.613801  3686.435477   8.0    16.0     1.0
# KEN           78.887602  2712.435477   5.0     6.0     1.0
# CHN           96.660000  3769.000000   2.0     2.0     2.0
# GER          160.610000  6600.000000   2.0     0.0     1.0
# ...                 ...          ...   ...     ...     ...
# GUM            3.430000   120.000000   0.0     0.0     0.0
# GUY            6.650000   253.000000   0.0     0.0     0.0
# HAI            5.431900   306.717738   0.0     0.0     0.0
# HKG            3.300000   105.000000   0.0     0.0     0.0
# ZIM           10.080000   367.000000   0.0     0.0     0.0
#
# [200 rows x 5 columns]

# %%
df2 = athletics.groupby("nationality").sum().sort_values("silver", ascending= False)
df2
# Out:
#                  height       weight  gold  silver  bronze
# nationality
# JAM           89.613801  3686.435477   8.0    16.0     1.0
# USA          227.699502  9457.588691  25.0     9.0     9.0
# KEN           78.887602  2712.435477   5.0     6.0     1.0
# JPN           89.500000  3177.000000   0.0     4.0     1.0
# FRA           95.290000  3624.000000   0.0     3.0     3.0
# ...                 ...          ...   ...     ...     ...
# GUY            6.650000   253.000000   0.0     0.0     0.0
# HAI            5.431900   306.717738   0.0     0.0     0.0
# HKG            3.300000   105.000000   0.0     0.0     0.0
# HON            1.890000    89.000000   0.0     0.0     0.0
# ZIM           10.080000   367.000000   0.0     0.0     0.0
#
# [200 rows x 5 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, JAM to ZIM
# Data columns (total 5 columns):
# height    200 non-null float64
# weight    200 non-null float64
# gold      200 non-null float64
# silver    200 non-null float64
# bronze    200 non-null float64
# dtypes: float64(5)
# memory usage: 9.4+ KB

# %%
df2.eval('medals = gold + silver + bronze',inplace=True)
df2
# Out:
#                  height       weight  gold  silver  bronze  medals
# nationality
# JAM           89.613801  3686.435477   8.0    16.0     1.0    25.0
# USA          227.699502  9457.588691  25.0     9.0     9.0    43.0
# KEN           78.887602  2712.435477   5.0     6.0     1.0    12.0
# JPN           89.500000  3177.000000   0.0     4.0     1.0     5.0
# FRA           95.290000  3624.000000   0.0     3.0     3.0     6.0
# ...                 ...          ...   ...     ...     ...     ...
# GUY            6.650000   253.000000   0.0     0.0     0.0     0.0
# HAI            5.431900   306.717738   0.0     0.0     0.0     0.0
# HKG            3.300000   105.000000   0.0     0.0     0.0     0.0
# HON            1.890000    89.000000   0.0     0.0     0.0     0.0
# ZIM           10.080000   367.000000   0.0     0.0     0.0     0.0
#
# [200 rows x 6 columns]

# %%
df2.to_csv('../../Sources/athletics_clean.csv', sep=",")

# %% [markdown]
# # cycling

# %%
df3 = cycling.groupby("nationality").sum().sort_values("silver", ascending= False)

# %%
df3.eval('medals = gold + silver + bronze',inplace=True)
df3
# Out:
#                 height       weight  gold  silver  bronze  medals
# nationality
# USA          36.390000  1400.000000   2.0     6.0     0.0     8.0
# AUS          51.106626  2063.755102   0.0     5.0     0.0     5.0
# GBR          42.780000  1700.000000  13.0     4.0     2.0    19.0
# RUS          20.623252   829.510204   0.0     3.0     1.0     4.0
# NZL          35.440000  1443.000000   0.0     3.0     0.0     3.0
# ...                ...          ...   ...     ...     ...     ...
# FIN           1.640000    58.000000   0.0     0.0     0.0     0.0
# ETH           1.750000    63.000000   0.0     0.0     0.0     0.0
# EST           3.630000   141.000000   0.0     0.0     0.0     0.0
# ESP          20.950000   803.000000   0.0     0.0     1.0     1.0
# VEN          15.400000   624.000000   0.0     0.0     1.0     1.0
#
# [79 rows x 6 columns]

# %%
df3.to_csv('../../Sources/cyclist_clean.csv', sep=",")
