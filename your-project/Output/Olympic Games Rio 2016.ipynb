# %%
from IPython.display import Image

# %% [markdown]
# # Atheltics

# %% [markdown]
# ![heatmap_ath](Images/heatmap_ath.png)

# %% [markdown]
# # Cycling

# %% [markdown]
# ![heatmap_ath](Images/cycl_heat.png)

# %%
from IPython.display import Image

# %%
Image("Images/rio_all_sports.png")

# %%
Image("Images/treemap_rio.png")

# %%
Image("Images/medal_comparison.png")

# %%
Image("Images/performance_coefficient.png")
